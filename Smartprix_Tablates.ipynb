# %%
with open('tablates.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup

# %%
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')
soup
# Out:
# <html class="way-item-finder" lang="en" style="--window-width:1366;"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><title> Tablets Price List in India 2023 | Smartprix</title><link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><meta content="#4692F0" name="theme-color"/><link href="/manifest.json" rel="manifest"/><meta content="171761809591603" property="fb:app_id"/><meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/><link href="https://www.smartprix.com/tablets" rel="canonical"/><meta content="Smartprix" property="og:site_name"/><meta content="@smartprix" name="twitter:site"/><meta content="@smartprix" name="twitter:creator"/><meta content="summary" name="twitter:card"/><link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/><script type="application/ld+json">{"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}</script><script type="application/ld+json">{"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"OnePlus Pad Tablet","url":"https://www.smartprix.com/tablets/oneplus-pad-tablet-ppd17ng9egwr","image":["https://cdn1.smartprix.com/rx-iSvIb51Mn-w1200-h1200/SvIb51Mn.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Apple iPad 9th Gen 10.2 2021 Tablet (Wi-Fi+64GB)","url":"https://www.smartprix.com/tablets/apple-ipad-9th-gen-10-2-2021-tablet-wi-fi-ppd15h8hiszg","image":["https://cdn1.smartprix.com/rx-iPZ43Te96-w1200-h1200/PZ43Te96.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Samsung Galaxy Tab A9 Tablet","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-a9-tablet-ppd1x6ta8hpv","image":["https://cdn1.smartprix.com/rx-iemNikZaC-w1200-h1200/emNikZaC.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Xiaomi Redmi Pad (6GB RAM + 128GB)","url":"https://www.smartprix.com/tablets/xiaomi-redmi-pad-6gb-ram-128gb-ppd1axkv9shg","image":["https://cdn1.smartprix.com/rx-ijZ9h7Ava-w1200-h1200/jZ9h7Ava.webp"]},{"@type":"ListIt
td>Vivo Pad Tablet</td><td>₹28,990</td><td>Upcoming</td></tr></tbody></table></div><span><a class="" role="button">Read More</a></span></div><div class="sm-page-actions finder"><ul><!-- --><!-- --><li><svg class="icon" style="--s:20px;" viewbox="0 0 24 24"><path d="M12.1,18.55L12,18.65L11.89,18.55C7.14,14.24 4,11.39 4,8.5C4,6.5 5.5,5 7.5,5C9.04,5 10.54,6 11.07,7.36H12.93C13.46,6 14.96,5 16.5,5C18.5,5 20,6.5 20,8.5C20,11.39 16.86,14.24 12.1,18.55M16.5,3C14.76,3 13.09,3.81 12,5.08C10.91,3.81 9.24,3 7.5,3C4.42,3 2,5.41 2,8.5C2,12.27 5.4,15.36 10.55,20.03L12,21.35L13.45,20.03C18.6,15.36 22,12.27 22,8.5C22,5.41 19.58,3 16.5,3Z"></path></svg><span>Like</span></li><li><svg class="icon" style="--s:20px;" viewbox="0 0 24 24"><path d="M18,8H6V6H18V8M18,11H6V9H18V11M18,14H6V12H18V14M22,4A2,2 0 0,0 20,2H4A2,2 0 0,0 2,4V16A2,2 0 0,0 4,18H18L22,22V4Z"></path></svg><span>Comment</span></li><li><svg class="icon" style="--s:20px;" viewbox="0 0 24 24"><path d="M18,16.08C17.24,16.08 16.56,16.38 16.04,16.85L8.91,12.7C8.96,12.47 9,12.24 9,12C9,11.76 8.96,11.53 8.91,11.3L15.96,7.19C16.5,7.69 17.21,8 18,8A3,3 0 0,0 21,5A3,3 0 0,0 18,2A3,3 0 0,0 15,5C15,5.24 15.04,5.47 15.09,5.7L8.04,9.81C7.5,9.31 6.79,9 6,9A3,3 0 0,0 3,12A3,3 0 0,0 6,15C6.79,15 7.5,14.69 8.04,14.19L15.16,18.34C15.11,18.55 15.08,18.77 15.08,19C15.08,20.61 16.39,21.91 18,21.91C19.61,21.91 20.92,20.61 20.92,19A2.92,2.92 0 0,0 18,16.08Z"></path></svg><span>Share</span></li></ul></div><!--]--></div><sm-dap class="p-d t-d" pos="d_finder_below_title_box" style="--w:728;--h:90;"><div><div data-google-query-id="CLH_-K_BkP0CFejScwEdVBELxA" id="sm-da-d_finder_below_title_box"><div id="google_ads_iframe_/88811612/d_finder_below_title_box_0__container__" style="border: 0pt none; display: inline-block; width: 728px; height: 90px;"><iframe aria-label="Advertisement" data-google-container-id="1" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/88811612/d_finder_below_title_box_0" marginheight="0" marginwidth="0" name="" role="region" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://a81bcec317f78a743215da157c19c9ab.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="border: 0px; vertical-align: bottom;" tabindex="0" title="3rd party ad content" width="728"></iframe></div></div></div></sm-dap><!-- --><div class="sm-dyn-content"><!--[--><!--[--><!--[--><div class="sm-box" style="background:aliceblue;"><div class="sm-box-header"><div class="sm-b ...

# %%
len(soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}))
# Out:
# 468

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 468

# %%
len(prices)
# Out:
# 468

# %%
len(ratings)
# Out:
# 468

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings
})

# %%
df.isnull().sum()
# Out:
# model       0
# price       0
# rating    154
# dtype: int64

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                                 model    price rating  \
# 0                                  OnePlus Pad Tablet  ₹39,999     76
# 1    Apple iPad 9th Gen 10.2 2021 Tablet (Wi-Fi+64GB)  ₹30,900    NaN
# 2                        Samsung Galaxy Tab A9 Tablet  ₹22,990     76
# 3                  Xiaomi Redmi Pad (6GB RAM + 128GB)  ₹19,499     70
# 4                       Xiaomi Mi Pad 5 Pro 5G Tablet  ₹39,999     87
# ..                                                ...      ...    ...
# 463                        Alcatel One Touch Evo 7 HD  ₹10,000    NaN
# 464                        Alcatel One Touch Tab 8 HD  ₹10,000    NaN
# 465                           Alcatel One Touch Tab 7   ₹8,000    NaN
# 466                        Alcatel One Touch Tab 7 HD   ₹9,000    NaN
# 467                              Sony Xperia Tablet S  ₹30,000    NaN
#
#                   sim                 processor  \
# 0               Wi-Fi                     No 3G
# 1               Wi-Fi                     No 3G
# 2          Single Sim  3G, 4G, 5G, VoLTE, Wi-Fi
# 3               Wi-Fi                     No 3G
# 4          Single Sim  3G, 4G, 5G, VoLTE, Wi-Fi
# ..                ...                       ...
# 463  No Sim Supported                     Wi-Fi
# 464  No Sim Supported                     Wi-Fi
# 465  No Sim Supported                     Wi-Fi
# 466  No Sim Supported                     Wi-Fi
# 467  No Sim Supported               Wi-Fi, HDMI
#
#                                                 ram                   battery  \
# 0     Dimensity 9000, Octa Core, 3.05 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1         Bionic A13, Hexa Core, 2.65 GHz Processor             64 GB inbuilt
# 2    Dimensity 700 5G, Octa Core, 2.2 GHz Processor   4 GB RAM, 64 GB inbuilt
# 3           Helio G99, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Snapdragon  870 , Octa Core, 3.2 GHz Processor  8 GB RAM, 256 GB inbuilt
# ..                                              ...                       ...
# 463                    Dual Core, 1.6 GHz Processor              4 GB inbuilt
# 464                    Dual Core, 1.6 GHz Processor              8 GB inbuilt
# 465                    Single Core, 1 GHz Processor              4 GB inbuilt
# 466                    Dual Core, 1.6 GHz Processor              8 GB inbuilt
# 467                    Quad Core, 1.3 GHz Processor   1 GB RAM, 64 GB inbuilt
#
#                                      display  \
# 0    9510 mAh Battery with 67W Fast Charging
# 1        10.2 inches, 2160 x 1620 px Display
# 2    8040 mAh Battery with 25W Fast Charging
# 3    8000 mAh Battery with 18W Fast Charging
# 4    8600 mAh Battery with 67W Fast Charging
# ..                                       ...
# 463          7 inches, 800 x 1280 px Display
# 464          8 inches, 768 x 1024 px Display
# 465          7 inches, 600 x 1024 px Display
# 466          7 inches, 800 x 1280 px Display
# 467                         6000 mAh Battery
#
#                                            camera  \
# 0    11.61 inches, 2000 x 2800 px, 144 Hz Display
# 1                  8 MP Rear & 12 MP Front Camera
# 2    10.58 inches, 1200 x 2000 px, 120 Hz Display
# 3     10.61 inches, 1200 x 2000 px, 90 Hz Display
# 4       11 inches, 1600 x 2560 px, 120 Hz Display
# ..                                            ...
# 463               3 MP Rear & 0.3 MP Front Camera
# 464               2 MP Rear & 0.3 MP Front Camera
# 465                            0.3 MP Rear Camera
# 466               2 MP Rear & 0.3 MP Front Camera
# 467             9.4 inches, 800 x 1280 px Display
#
#                                            card  \
# 0                13 MP Rear & 8 MP Front Camera
# 1                                       iOS v15
# 2                13 MP Rear & 5 MP Front Camera
# 3                 8 MP Rear & 8 MP Front Camera
# 4    50 MP + 5 MP Dual Rear & 8 MP Front Camera
# ..                                          ...
# 463           Memory Card Supported, upto 32 GB
# 464           Memory Card Supported, upto 32 GB
# 465           Memory Card Supported, upto 32 GB
# 466           Memory Card Supported, upto 32 GB
# 467               8 MP Rear & 1 MP Front Camera
#
#                                     os
# 0                        Android v13.1
# 1                          No FM Radio
# 2     Memory Card Supported, upto 1 TB
# 3     Memory Card Supported, upto 1 TB
# 4                          Android v11
# ..                                 ...
# 463          Android v4.1 (Jelly Bean)
# 464          Android v4.1 (Jelly Bean)
# 465          Android v4.1 (Jelly Bean)
# 466          Android v4.1 (Jelly Bean)
# 467  Memory Card Supported, upto 32 GB
#
# [468 rows x 11 columns]

# %%
df.to_csv('Smartprix_Tablates.csv')
